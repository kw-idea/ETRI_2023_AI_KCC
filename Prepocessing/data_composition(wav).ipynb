# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import glob
import os
import time

import numpy as np
import pandas as pd
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/데이터/KFold/Subset1.csv', encoding = 'utf-8', index_col=0)
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/데이터/KFold/Subset2.csv', encoding = 'utf-8', index_col=0)
df3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/데이터/KFold/Subset3.csv', encoding = 'utf-8', index_col=0)
df4 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/데이터/KFold/Subset4.csv', encoding = 'utf-8', index_col=0)
df5 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/데이터/KFold/Subset5.csv', encoding = 'utf-8', index_col=0)

# %%
file_path19 = "/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/곽소정/data/wav19/"
file_path20 = "/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/곽소정/data/wav20/"

# %% [markdown]
# #df1

# %%
df1
# Out:
#       Wav_start  Wav_end               Speaker  Emotion  Valence  Arousal  \
# 0        15.476   19.786  Sess01_script01_F001     fear      1.5      3.6
# 1        28.943   32.167  Sess01_script01_F002     fear      1.6      3.7
# 2        39.264   46.833  Sess01_script01_F003     fear      1.4      4.1
# 3        73.016   83.209  Sess01_script01_F005     fear      1.5      3.5
# 4        97.483  105.530  Sess01_script01_F006     fear      1.4      4.0
# ...         ...      ...                   ...      ...      ...      ...
# 4660     18.443   20.428   Sess13_impro03_F004  neutral      3.5      3.0
# 4661     21.755   23.651   Sess13_impro03_F005  neutral      3.3      3.0
# 4662     27.833   36.556   Sess13_impro03_F006  neutral      3.1      2.9
# 4663     37.481   40.929   Sess13_impro03_F007  neutral      3.0      3.2
# 4664     48.031   54.349   Sess13_impro03_F008  neutral      3.7      3.1
#
#       IBI_mean  IBI_count   IBI_std  IBI_max  ...  TEMP_max  TEMP_min  \
# ...

# %%
file_list = os.listdir(file_path19) + os.listdir(file_path20)

# %%
df1["path"] = np.where( df1["Year"].values == 19 , file_path19 + df1['Speaker'] + ".wav", file_path20 + df1['Speaker'] + ".wav")
df2["path"] = np.where( df2["Year"].values == 19 , file_path19 + df2['Speaker'] + ".wav", file_path20 + df2['Speaker'] + ".wav")
df3["path"] = np.where( df3["Year"].values == 19 , file_path19 + df3['Speaker'] + ".wav", file_path20 + df3['Speaker'] + ".wav")
df4["path"] = np.where( df4["Year"].values == 19 , file_path19 + df4['Speaker'] + ".wav", file_path20 + df4['Speaker'] + ".wav")
df5["path"] = np.where( df5["Year"].values == 19 , file_path19 + df5['Speaker'] + ".wav", file_path20 + df5['Speaker'] + ".wav")

# %%
df1 = df1.reset_index()
df1 = df1.drop(columns = 'index')
df2 = df2.reset_index()
df2 = df2.drop(columns = 'index')
df3 = df3.reset_index()
df3 = df3.drop(columns = 'index')
df4 = df4.reset_index()
df4 = df4.drop(columns = 'index')
df5 = df5.reset_index()
df5 = df5.drop(columns = 'index')

# %%
df1
# Out:
#       Wav_start  Wav_end               Speaker  Emotion  Valence  Arousal  \
# 0        15.476   19.786  Sess01_script01_F001     fear      1.5      3.6
# 1        28.943   32.167  Sess01_script01_F002     fear      1.6      3.7
# 2        39.264   46.833  Sess01_script01_F003     fear      1.4      4.1
# 3        73.016   83.209  Sess01_script01_F005     fear      1.5      3.5
# 4        97.483  105.530  Sess01_script01_F006     fear      1.4      4.0
# ...         ...      ...                   ...      ...      ...      ...
# 3055     18.443   20.428   Sess13_impro03_F004  neutral      3.5      3.0
# 3056     21.755   23.651   Sess13_impro03_F005  neutral      3.3      3.0
# 3057     27.833   36.556   Sess13_impro03_F006  neutral      3.1      2.9
# 3058     37.481   40.929   Sess13_impro03_F007  neutral      3.0      3.2
# 3059     48.031   54.349   Sess13_impro03_F008  neutral      3.7      3.1
#
#       IBI_mean  IBI_count   IBI_std  IBI_max  ...  TEMP_min  TEMP_range  \
# ...

# %%
df2
# Out:
#       Wav_start    Wav_end                       Speaker  Emotion  Valence  \
# 0     173.89300  183.77100          Sess04_script04_F016     fear      1.6
# 1     196.34800  200.81200          Sess04_script04_F018     fear      1.4
# 2     217.27700  221.50800          Sess04_script04_F019     fear      1.5
# 3     249.88900  254.47800          Sess04_script04_F020     fear      1.5
# 4      38.50800   39.70000          Sess04_script04_M005     fear      2.0
# ...         ...        ...                           ...      ...      ...
# 3055  239.97745  241.83046  Sess09_script04_User017M_026  neutral      2.9
# 3056  241.83046  251.34247  Sess09_script04_User017M_027  neutral      2.5
# 3057  241.92100  243.56100  Sess09_script04_User018M_034  neutral      3.0
# 3058  253.34500  256.15400  Sess09_script04_User018M_035  neutral      3.1
# 3059  256.15400  258.19800  Sess09_script04_User018M_036  neutral      2.9
#
# ...

# %%
df3
# Out:
#       Wav_start    Wav_end                       Speaker  Emotion  Valence  \
# 0       108.396  118.78700          Sess07_script05_M012     fear      2.2
# 1       129.327  134.95100          Sess07_script05_M014     fear      1.4
# 2       136.333  142.80500          Sess07_script05_M015     fear      1.4
# 3       153.662  169.68600           Sess07_impro03_M019     fear      1.6
# 4        81.333   89.94800          Sess08_script03_F006     fear      1.4
# ...         ...        ...                           ...      ...      ...
# 3055    193.401  195.71701  Sess23_script02_User046M_018  neutral      2.8
# 3056    199.210  204.55200  Sess23_script02_User046M_019  neutral      2.8
# 3057    224.947  226.72000  Sess23_script02_User046M_020  neutral      2.8
# 3058    226.720  231.96501  Sess23_script02_User046M_021  neutral      2.8
# 3059    240.250  249.53102  Sess23_script02_User046M_022  neutral      2.3
#
# ...

# %%
df4
# Out:
#       Wav_start    Wav_end                       Speaker  Emotion  Valence  \
# 0     214.58700  220.28800           Sess11_impro03_F021     fear      1.6
# 1     234.29400  248.36400           Sess11_impro03_F023     fear      1.5
# 2      31.69400   37.78300          Sess11_script05_M005     fear      1.8
# 3      69.23400   71.97300          Sess11_script05_M009     fear      1.9
# 4     108.72600  116.02600          Sess11_script05_M014     fear      1.8
# ...         ...        ...                           ...      ...      ...
# 3054  153.98601  158.07500  Sess33_script01_User065M_012  neutral      2.6
# 3055  158.07500  160.26400  Sess33_script01_User065M_013  neutral      3.4
# 3056  159.88501  164.45999  Sess33_script01_User066M_019  neutral      3.1
# 3057  165.97800  167.32000  Sess33_script01_User066M_020  neutral      3.0
# 3058  176.06400  179.16602  Sess33_script01_User066M_022  neutral      3.0
#
# ...

# %%
df5
# Out:
#       Wav_start  Wav_end                       Speaker  Emotion  Valence  \
# 0     189.69500  191.463          Sess17_script05_F014     fear      1.6
# 1     205.21900  207.521          Sess17_script05_F015     fear      1.5
# 2     234.07500  236.106          Sess17_script05_F016     fear      1.7
# 3     289.09200  291.480          Sess17_script05_F022     fear      1.3
# 4      52.19300   65.240          Sess17_script05_M005     fear      1.6
# ...         ...      ...                           ...      ...      ...
# 3054  289.44998  294.943  Sess40_script06_User079F_043  neutral      3.0
# 3055  294.94300  297.598  Sess40_script06_User079F_044  neutral      2.9
# 3056  297.59800  304.171  Sess40_script06_User079F_045  neutral      2.6
# 3057  304.17100  306.863  Sess40_script06_User079F_046  neutral      2.7
# 3058  306.86300  309.107  Sess40_script06_User079F_047  neutral      2.9
#
#       Arousal  IBI_mean  IBI_count   IBI_std   IBI_max  ...  TEMP_min  \
# ...

# %%
df1.to_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/곽소정/data/data1.csv',encoding="utf-8",index = False)
df2.to_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/곽소정/data/data2.csv',encoding="utf-8",index = False)
df3.to_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/곽소정/data/data3.csv',encoding="utf-8",index = False)
df4.to_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/곽소정/data/data4.csv',encoding="utf-8",index = False)
df5.to_csv('/content/drive/MyDrive/Colab Notebooks/2023 휴먼이해 공모전/곽소정/data/data5.csv',encoding="utf-8",index = False)
